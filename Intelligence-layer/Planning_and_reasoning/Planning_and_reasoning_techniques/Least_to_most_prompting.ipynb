# %% [markdown]
# # Least-to-most prompting
#
# Complex problems often overwhelm language models when presented all at once. A sophisticated question requiring multiple reasoning steps, domain knowledge, and careful integration of information can exceed the model's ability to handle everything simultaneously. This is particularly true when problems have hierarchical structure - solving the overall problem depends on first solving simpler sub-problems.
#
# Least-to-Most prompting addresses this by explicitly decomposing complex problems into a sequence of simpler sub-problems, solving them from easiest to hardest, and using each solution as context for the next. The technique consists of two stages: decomposition (break the problem into ordered sub-problems) and sequential solving (solve each sub-problem using previous solutions as context). This builds up understanding incrementally rather than requiring the model to handle all complexity at once.
#
# In this notebook, we will implement Least-to-Most prompting to show how progressive problem decomposition improves reasoning on complex tasks. We will create a system that breaks down challenging questions into manageable pieces, solves them in order of increasing difficulty and builds each solution on previous ones. This approach is particularly effective for compositional reasoning, mathematical proofs, multi-hop question answering and any problem with natural hierarchical structure.

# %%
import os
from typing import List, Dict, Any, Optional
from dataclasses import dataclass
from langchain_openai import ChatOpenAI
from langchain_core.messages import SystemMessage, HumanMessage

# %% [markdown]
# We will use dataclasses to represent sub-problems and their solutions, maintaining clear structure as we build up from simple to complex.
#
# ### Initialize the language model
# In Least-to-Most prompting, the language model serves dual purposes: decomposing problems into sub-problems and solving each sub-problem. We use a moderate temperature to allow flexibility in decomposition while maintaining logical consistency in solutions.

# %%
# Initialize the language model
# Using temperature=0.5 for balanced decomposition and solving
llm = ChatOpenAI(
    model="gpt-4o-mini",
    api_key=os.getenv("OPENAI_API_KEY", "").strip(),
    temperature=0.5  # Moderate temperature for flexibility with consistency
)

# %% [markdown]
# Temperature 0.5 provides a good balance - creative enough to identify helpful decompositions, but consistent enough to produce reliable solutions to sub-problems.
#
# ## Define data structures
# We need structures to represent sub-problems and track the solving process. Each sub-problem has a description and its solution. The solver maintains the progression from simple to complex, using earlier solutions as context for later ones.

# %%
@dataclass
class SubProblem:
    """
    Represents a single sub-problem in the decomposition.
    """
    index: int  # Order in the sequence (0 is simplest)
    description: str  # What this sub-problem asks
    solution: Optional[str] = None  # The answer (filled during solving)
    
    def is_solved(self) -> bool:
        """Check if this sub-problem has been solved."""
        return self.solution is not None
    
    def __repr__(self):
        """Pretty print representation."""
        status = "✓" if self.is_solved() else "○"
        return f"{status} Sub-problem {self.index + 1}: {self.description}"


@dataclass  
class DecompositionResult:
    """
    Result of decomposing a problem into sub-problems.
    """
    original_problem: str  # The original complex problem
    sub_problems: List[SubProblem]  # Ordered list from simplest to hardest
    
    def __repr__(self):
        """Pretty print the decomposition."""
        result = f"Original: {self.original_problem}\n\nSub-problems:\n"
        for sp in self.sub_problems:
            result += f"  {sp}\n"
        return result

# %% [markdown]
# - The `SubProblem` class represents individual sub-problems with their solutions.
# - The `DecompositionResult` maintains the ordered sequence.
#
# The ordering is crucial - we solve simpler problems first, using those solutions as building blocks for harder ones.
#
# ## Implement problem decomposition
# The first stage of Least-to-Most is decomposition. We prompt the LLM to break the complex problem into simpler sub-problems, ordered from easiest to hardest. Good decomposition identifies natural sub-problems where each builds on previous ones.

# %%
def decompose_problem(problem: str, num_subproblems: int = 4) -> DecompositionResult:
    """
    Decompose a complex problem into simpler sub-problems.
    Orders them from least to most complex.
    
    Args:
        problem: The complex problem to decompose
        num_subproblems: Target number of sub-problems
    
    Returns:
        DecompositionResult with ordered sub-problems
    """
    # Create decomposition prompt
    system_message = SystemMessage(
        content=f"""You are an expert at breaking down complex problems into simpler sub-problems.
        
        Decompose the given problem into approximately {num_subproblems} sub-problems, ordered from SIMPLEST to MOST COMPLEX.
        Each sub-problem should build on the previous ones.
        
        Format your response as a numbered list:
        1. [First/simplest sub-problem]
        2. [Second sub-problem]
        3. [Third sub-problem]
        etc.
        
        Make each sub-problem clear and self-contained.
        """
    )
    
    user_message = HumanMessage(
        content=f"""Problem to decompose: {problem}
        
        Break this into simpler sub-problems:"""
    )
    
    # Get decomposition from LLM
    response = llm.invoke([system_message, user_message])
    decomposition_text = response.content
    
    # Parse the decomposition into SubProblem objects
    sub_problems = []
    lines = decomposition_text.split('\n')
    
    for line in lines:
        # Look for numbered lines (1., 2., etc.)
        line = line.strip()
        if line and line[0].isdigit():
            # Extract the sub-problem description
            # Remove the number prefix
            parts = line.split('.', 1)
            if len(parts) == 2:
                description = parts[1].strip()
                # Remove any markdown formatting
                description = description.strip('*').strip()
                if description:
                    sub_problems.append(
                        SubProblem(
                            index=len(sub_problems),
                            description=description
                        )
                    )
    
    return DecompositionResult(
        original_problem=problem,
        sub_problems=sub_problems
    )


# Test decomposition
test_problem = """A company wants to expand from 50 to 200 employees over 2 years.
They need to hire staff, find office space, and set up infrastructure.
What's a reasonable budget and timeline for this expansion?"""

decomposition = decompose_problem(test_problem)
print("=== Problem Decomposition ===")
print(decomposition)
# Out:
# === Problem Decomposition ===
# Original: A company wants to expand from 50 to 200 employees over 2 years.
# They need to hire staff, find office space, and set up infrastructure.
# What's a reasonable budget and timeline for this expansion?
#
# Sub-problems:
#   ○ Sub-problem 1: Determine the Staffing Needs**: Identify the specific roles and number of employees required for the expansion. This includes breaking down the types of positions needed (e.g., management, technical, administrative) and estimating the hiring timeline for each role.
#   ○ Sub-problem 2: Estimate Hiring Costs**: Calculate the costs associated with the hiring process, including recruitment expenses (job postings, recruitment agency fees), salaries for the new employees, and any associated benefits. This should also include the costs for onboarding and training new hires.
#   ○ Sub-problem 3: Identify Office Space Requirements**: Assess the space needed to accommodate the new employees. This involves determining the square footage required per employee, considering the layout (e.g., open plan vs. cubicles), and researching potential office locations that fit the company's budget and needs.
#   ○ Sub-problem 4: Develop a Comprehensive Budget and Timeline**: Combine the staffing needs, hiring costs, and office space requirements to create a detailed budget for the expansion. Additionally, outline a timeline that includes milestones for hiring, securing office space, and setting up infrastructure, ensuring that all elements align with the goal of reaching 200 employees in 2 years.

# %% [markdown]
# - The `decompose_problem()` function prompts the LLM to break down complexity into manageable pieces.
# - The prompt explicitly requests ordering from simplest to most complex - this is key to Least-to-Most.
# - We parse the response into structured `SubProblem` objects for systematic solving. Good decompositions have sub-problems where later ones naturally build on earlier answers.
#
# ## Implement sequential solving
# The second stage solves each sub-problem in order, using previous solutions as context. This is the "most" part - we progressively tackle more complex sub-problems, leveraging what we have already solved. Each solution becomes part of the context for the next sub-problem.

# %%
def solve_subproblem(
    subproblem: SubProblem,
    previous_solutions: List[SubProblem],
    original_problem: str
) -> str:
    """
    Solve a single sub-problem using previous solutions as context.
    This is the core of Least-to-Most: building on previous answers.
    
    Args:
        subproblem: The sub-problem to solve
        previous_solutions: Already-solved sub-problems to use as context
        original_problem: The original complex problem (for context)
    
    Returns:
        Solution to this sub-problem
    """
    # Build context from previous solutions
    context = f"Original problem: {original_problem}\n\n"
    
    if previous_solutions:
        context += "Previous sub-problems and their solutions:\n"
        for prev in previous_solutions:
            context += f"\nQ{prev.index + 1}: {prev.description}\n"
            context += f"A{prev.index + 1}: {prev.solution}\n"
    else:
        context += "This is the first sub-problem.\n"
    
    # Create solving prompt
    system_message = SystemMessage(
        content="""You are solving sub-problems as part of a larger problem.
        Use the previous sub-problem solutions to help answer the current one.
        Be specific and build on what's already been established.
        """
    )
    
    user_message = HumanMessage(
        content=f"{context}\nCurrent sub-problem to solve:\n{subproblem.description}\n\nProvide a clear, specific answer:"
    )
    
    # Get solution from LLM
    response = llm.invoke([system_message, user_message])
    return response.content


def solve_sequentially(decomposition: DecompositionResult) -> List[SubProblem]:
    """
    Solve all sub-problems in order, each using previous solutions as context.
    
    Args:
        decomposition: The decomposed problem
    
    Returns:
        List of solved sub-problems
    """
    print("\n=== Sequential Solving ===")
    print(f"Solving {len(decomposition.sub_problems)} sub-problems from simplest to most complex...\n")
    
    solved_problems = []
    
    for subproblem in decomposition.sub_problems:
        print(f"[Sub-problem {subproblem.index + 1}/{len(decomposition.sub_problems)}]")
        print(f"Question: {subproblem.description}")
        
        # Solve using previous solutions as context
        solution = solve_subproblem(
            subproblem,
            solved_problems,  # Pass all previously solved sub-problems
            decomposition.original_problem
        )
        
        # Update the sub-problem with its solution
        subproblem.solution = solution
        solved_problems.append(subproblem)
        
        print(f"Answer: {solution[:150]}..." if len(solution) > 150 else f"Answer: {solution}")
        print()
    
    return solved_problems


# Test sequential solving
solved = solve_sequentially(decomposition)
# Out:
# === Sequential Solving ===
# Solving 4 sub-problems from simplest to most complex...
#
# [Sub-problem 1/4]
# Question: Determine the Staffing Needs**: Identify the specific roles and number of employees required for the expansion. This includes breaking down the types of positions needed (e.g., management, technical, administrative) and estimating the hiring timeline for each role.
# Answer: To determine the staffing needs for the company's expansion from 50 to 200 employees, we can break down the roles into three main categories: manageme...
#
# [Sub-problem 2/4]
# Question: Estimate Hiring Costs**: Calculate the costs associated with the hiring process, including recruitment expenses (job postings, recruitment agency fees), salaries for the new employees, and any associated benefits. This should also include the costs for onboarding and training new hires.
# Answer: To estimate the hiring costs associated with expanding the company from 50 to 200 employees, we will consider several components: recruitment expenses...
#
# [Sub-problem 3/4]
# Question: Identify Office Space Requirements**: Assess the space needed to accommodate the new employees. This involves determining the square footage required per employee, considering the layout (e.g., open plan vs. cubicles), and researching potential office locations that fit the company's budget and needs.
# Answer: To identify the office space requirements for accommodating the new employees as the company expands from 50 to 200 employees, we need to consider sev...
#
# [Sub-problem 4/4]
# Question: Develop a Comprehensive Budget and Timeline**: Combine the staffing needs, hiring costs, and office space requirements to create a detailed budget for the expansion. Additionally, outline a timeline that includes milestones for hiring, securing office space, and setting up infrastructure, ensuring that all elements align with the goal of reaching 200 employees in 2 years.
# Answer: To develop a comprehensive budget and timeline for the company's expansion from 50 to 200 employees over 2 years, we will consolidate the staffing nee...

# %% [markdown]
# The `solve_subproblem()` function is where Least-to-Most shines. It provides all previous solutions as context, allowing the model to build incrementally. The `solve_sequentially()` function orchestrates this process, maintaining the progression from simple to complex. Each sub-problem benefits from what came before - this is how we handle complexity that would overwhelm the model if presented all at once.
#
# ## Synthesize final answer
# After solving all sub-problems, we synthesize them into a comprehensive answer to the original question. This synthesis step combines the sub-problem solutions into a coherent whole, addressing the original complex problem.

# %%
def synthesize_final_answer(
    original_problem: str,
    solved_subproblems: List[SubProblem]
) -> str:
    """
    Synthesize a final comprehensive answer from all sub-problem solutions.
    
    Args:
        original_problem: The original complex problem
        solved_subproblems: All solved sub-problems
    
    Returns:
        Comprehensive final answer
    """
    # Build context from all solutions
    context = "Sub-problems and their solutions:\n\n"
    for sp in solved_subproblems:
        context += f"Q: {sp.description}\n"
        context += f"A: {sp.solution}\n\n"
    
    # Create synthesis prompt
    system_message = SystemMessage(
        content="""You are synthesizing a comprehensive answer from sub-problem solutions.
        Combine the insights from all sub-problems into a clear, complete answer
        to the original question. Make it coherent and well-structured.
        """
    )
    
    user_message = HumanMessage(
        content=f"{context}\nOriginal problem: {original_problem}\n\nProvide a comprehensive final answer:"
    )
    
    # Get final answer
    response = llm.invoke([system_message, user_message])
    return response.content


# Synthesize final answer
final_answer = synthesize_final_answer(test_problem, solved)

print("=== Final Comprehensive Answer ===")
print(final_answer)
# Out:
# === Final Comprehensive Answer ===
# To facilitate the expansion of the company from 50 to 200 employees over a two-year period, we have developed a comprehensive budget and timeline that addresses staffing needs, hiring costs, office space requirements, and infrastructure setup. Below is the detailed plan:
#
# ### Comprehensive Budget
#
# 1. **Total Hiring Costs:**
#    - **Recruitment Expenses:**
#      - Job Postings: $60,000
#      - Recruitment Agency Fees: $2,100,000
#      - **Total Recruitment Expenses:** **$2,160,000**
#
#    - **Salaries:**
#      - Management Salaries: $600,000
#      - Technical Salaries: $1,680,000
#      - Administrative Salaries: $1,000,000
#      - **Total Salaries:** **$3,280,000**
#
#    - **Benefits:**
#      - Total Benefits Cost (30% of salaries): **$984,000**
#
#    - **Onboarding and Training Costs:**
#      - Total Onboarding and Training Costs: **$225,000**
#
#    - **Overall Total Hiring Costs:**
#      - **Total Hiring Costs = Recruitment Expenses + Salaries + Benefits + Onboarding Costs**
#      - **Total Hiring Costs = $2,160,000 + $3,280,000 + $984,000 + $225,000 = $6,649,000**
#
# 2. **Office Space Costs:**
#    - Estimated Annual Rent: $235,500
#    - Total Office Space Cost over 2 years:
#      - **Total Office Space Cost = Annual Rent * 2 = $235,500 * 2 = $471,000**
#
# 3. **Overall Budget Summary:**
#    - **Total Hiring Costs:** $6,649,000
#    - **Total Office Space Cost:** $471,000
#    - **Total Budget for Expansion:**
#      - **Total Budget = Hiring Costs + Office Space Costs**
#      - **Total Budget = $6,649,000 + $471,000 = $7,120,000**
#
# ### Comprehensive Timeline
#
# #### **Phase 1: Months 1-3 (Planning and Initial Hiring)**
# - **Milestones:**
#   - Finalize organizational structure and roles.
#   - Begin recruitment for management positions (Operations Manager, HR Manager).
#   - Start searching for office space.
#   - Post job openings and engage recruitment agencies.
#
# #### **Phase 2: Months 4-6 (Continued Hiring and Office Securing)**
# - **Milestones:**
#   - Hire Operations Manager and HR Manager.
#   - Continue recruitment for Sales Manager, IT Manager, and initial administrative roles (Administrative Assistants).
#   - Secure office space (finalize lease agreement).
#   - Begin office setup planning (layout, furniture, IT infrastructure).
#
# #### **Phase 3: Months 7-12 (Hiring Technical and Administrative Staff)**
# - **Milestones:**
#   - Hire Sales Manager and IT Manager.
#   - Hire 5 Software Developers and 3 Data Analysts.
#   - Hire Administrative Assistants and Customer Service Representatives.
#   - Begin onboarding processes for new hires.
#   - Start infrastructure setup (network, software, equipment).
#
# #### **Phase 4: Months 13-18 (Finalizing Hiring and Infrastructure)**
# - **Milestones:**
#   - Hire remaining technical staff (Systems Administrators, Quality Assurance Engineers).
#   - Complete hiring of remaining administrative staff (Customer Service Representatives, Marketing Specialists).
#   - Finalize office setup and infrastructure.
#   - Conduct training sessions for all new employees.
#
# #### **Phase 5: Months 19-24 (Expansion Completion)**
# - **Milestones:**
#   - Ensure all 200 employees are onboarded and operational.
#   - Evaluate the effectiveness of the new hires and infrastructure.
#   - Make adjustments as needed to optimize operations.
#   - Conduct a review of the expansion process and identify areas for improvement.
#
# ### Conclusion
# The total budget for the company's expansion from 50 to 200 employees over 2 years is approximately **$7,120,000**. The structured timeline includes five phases with specific milestones that ensure a systematic approach to hiring, securing office space, and setting up infrastructure. This comprehensive plan will facilitate a smooth transition and successful expansion for the company, allowing it to effectively scale its operations and workforce.

# %% [markdown]
# The `synthesize_final_answer()` function combines all sub-solutions into a coherent whole. It provides the full context of all sub-problems and solutions, asking the model to create a comprehensive answer. This synthesis step ensures we don't just have disconnected sub-answers, but an integrated response to the original complex question.

# %% [markdown]
# ## Create complete Least-to-Most solver
#
# Now we combine decomposition, sequential solving, and synthesis into a complete system that handles the full Least-to-Most workflow.

# %%
class LeastToMostSolver:
    """
    Complete Least-to-Most prompting solver.
    Decomposes problems, solves from simplest to most complex, synthesizes answer.
    """
    
    def solve(self, problem: str, verbose: bool = True) -> Dict[str, Any]:
        """
        Solve a complex problem using Least-to-Most prompting.
        
        Args:
            problem: The complex problem to solve
            verbose: Whether to print progress
        
        Returns:
            Dictionary with decomposition, solutions, and final answer
        """
        if verbose:
            print("=" * 80)
            print("LEAST-TO-MOST SOLVER")
            print("=" * 80)
            print(f"\nOriginal Problem: {problem}\n")
        
        # Stage 1: Decompose
        if verbose:
            print("[Stage 1: Decomposition]")
        decomposition = decompose_problem(problem)
        
        if verbose:
            print(f"Decomposed into {len(decomposition.sub_problems)} sub-problems:")
            for sp in decomposition.sub_problems:
                print(f"  {sp.index + 1}. {sp.description}")
        
        # Stage 2: Solve sequentially
        if verbose:
            print(f"\n[Stage 2: Sequential Solving]")
        solved = solve_sequentially(decomposition)
        
        # Stage 3: Synthesize
        if verbose:
            print("[Stage 3: Synthesis]")
        final_answer = synthesize_final_answer(problem, solved)
        
        if verbose:
            print("\n" + "=" * 80)
            print("FINAL ANSWER")
            print("=" * 80)
            print(final_answer)
        
        return {
            'problem': problem,
            'decomposition': decomposition,
            'solved_subproblems': solved,
            'final_answer': final_answer
        }


# Test the complete solver
solver = LeastToMostSolver()
result = solver.solve(
    "How can a small startup with 5 people and $50k budget launch a mobile app and get 10,000 users in 6 months?"
)
# Out:
# ================================================================================
# LEAST-TO-MOST SOLVER
# ================================================================================
#
# Original Problem: How can a small startup with 5 people and $50k budget launch a mobile app and get 10,000 users in 6 months?
#
# [Stage 1: Decomposition]
# Decomposed into 4 sub-problems:
#   1. Define the App Concept and Target Audience**: Identify the core features and functionalities of the mobile app, as well as the specific target audience. This includes conducting market research to understand user needs and preferences.
#   2. Develop a Minimum Viable Product (MVP)**: Create a basic version of the app that includes only the essential features necessary to meet the needs of the target audience. This involves planning the app's design, user interface, and technical requirements, and then allocating resources for development.
#   3. Establish a Marketing Strategy**: Formulate a marketing plan to promote the app and attract users. This includes selecting appropriate marketing channels (social media, content marketing, etc.), setting a budget for advertising, and creating promotional materials.
#   4. Launch the App and Implement User Acquisition Tactics**: Execute the app launch and apply user acquisition strategies to reach the goal of 10,000 users within 6 months. This may involve leveraging partnerships, running targeted ad campaigns, and engaging with the user community for feedback and referrals.
#
# [Stage 2: Sequential Solving]
#
# === Sequential Solving ===
# Solving 4 sub-problems from simplest to most complex...
#
# [Sub-problem 1/4]
# Question: Define the App Concept and Target Audience**: Identify the core features and functionalities of the mobile app, as well as the specific target audience. This includes conducting market research to understand user needs and preferences.
# Answer: To define the app concept and target audience for the mobile app, follow these steps:
#
# ### Step 1: Identify the App Concept
#
# 1. **Core Idea**: Start w...
#
# [Sub-problem 2/4]
# Question: Develop a Minimum Viable Product (MVP)**: Create a basic version of the app that includes only the essential features necessary to meet the needs of the target audience. This involves planning the app's design, user interface, and technical requirements, and then allocating resources for development.
# Answer: To develop a Minimum Viable Product (MVP) for the mobile app based on the previously defined concept and target audience, follow these steps:
#
# ### Ste...
#
# [Sub-problem 3/4]
# Question: Establish a Marketing Strategy**: Formulate a marketing plan to promote the app and attract users. This includes selecting appropriate marketing channels (social media, content marketing, etc.), setting a budget for advertising, and creating promotional materials.
# Answer: To establish a marketing strategy for the mobile app that aligns with the defined app concept, target audience, and MVP development, follow these step...
#
# [Sub-problem 4/4]
# Question: Launch the App and Implement User Acquisition Tactics**: Execute the app launch and apply user acquisition strategies to reach the goal of 10,000 users within 6 months. This may involve leveraging partnerships, running targeted ad campaigns, and engaging with the user community for feedback and referrals.
# Answer: To successfully launch the app and implement user acquisition tactics aimed at reaching 10,000 users within six months, follow these structured steps:...
#
# [Stage 3: Synthesis]
#
# ================================================================================
# FINAL ANSWER
# ================================================================================
# To successfully launch a mobile app and acquire 10,000 users within six months on a $50,000 budget with a small team of five, the startup should follow a structured approach encompassing app concept definition, MVP development, marketing strategy, and user acquisition tactics. Here’s a comprehensive plan:
#
# ### 1. Define the App Concept and Target Audience
#
# **Core Idea**: Focus on a health and wellness app, such as a fitness tracker that offers personalized workout plans and nutrition advice.
#
# **Core Features**:
# - **User Profiles**: Personalized tracking of fitness goals and dietary preferences.
# - **Workout Plans**: Customizable plans based on user input and fitness levels.
# - **Nutrition Tracking**: Basic meal logging to track calories and nutrients.
# - **Community Support**: A forum for users to connect and motivate each other.
# - **Push Notifications**: Reminders for workouts and meal logging to enhance engagement.
# - **Gamification**: Rewards and challenges to encourage consistent use.
#
# **Target Audience**:
# - **Demographics**: Primarily aged 18-35, both male and female, located in urban areas.
# - **Psychographics**: Health-conscious individuals, busy professionals, and socially motivated users who enjoy community engagement.
# - **User Personas**: Create detailed personas representing different segments of the target audience, focusing on their goals and challenges.
#
# ### 2. Develop a Minimum Viable Product (MVP)
#
# **Essential Features**:
# - User profiles
# - Customizable workout plans
# - Basic nutrition tracking
# - Community forum
# - Push notifications
#
# **Design and User Interface**:
# - Create wireframes for key screens and map out user flow to ensure intuitive navigation.
# - Establish a clean visual design that resonates with the target audience.
#
# **Technical Requirements**:
# - Choose a development platform (native vs. cross-platform).
# - Set up a backend for user data storage, using cloud services for scalability.
# - Identify necessary APIs for enhanced functionality.
#
# **Resource Allocation**:
# - Assign roles based on team skills (developers, designer, product manager, marketing specialist).
# - Allocate the budget strategically, with a significant portion dedicated to development and initial marketing efforts.
#
# ### 3. Establish a Marketing Strategy
#
# **Marketing Goals**:
# - Acquire 10,000 users within six months.
# - Increase brand awareness.
# - Foster user engagement and community.
#
# **Marketing Channels**:
# - **Social Media Marketing**: Focus on platforms like Instagram and TikTok, creating engaging content and collaborating with fitness influencers.
# - **Content Marketing**: Start a blog with SEO-optimized articles on fitness and nutrition, and build an email newsletter for regular updates.
# - **Community Engagement**: Create online forums or groups and organize fitness challenges to encourage user interaction.
# - **Paid Advertising**: Use targeted ads on social media and Google Ads to drive traffic to the app.
#
# **Budget Allocation**:
# - Allocate 30-40% of the budget for marketing efforts (approximately $15,000 to $20,000), broken down into social media ads, influencer partnerships, content creation, and community engagement.
#
# ### 4. Launch the App and Implement User Acquisition Tactics
#
# **Pre-Launch Activities**:
# - Create buzz through teaser campaigns and a dedicated landing page for early sign-ups.
# - Engage influencers for pre-launch promotions and conduct beta testing for feedback.
#
# **Launch Day**:
# - Distribute a press release and execute a social media blitz.
# - Optimize the app store listing and offer launch promotions to incentivize downloads.
#
# **User Acquisition Tactics**:
# - Run targeted advertising campaigns and establish a referral program to incentivize existing users to bring in new ones.
# - Maintain community engagement through social media and in-app features, and utilize email marketing to keep users informed and engaged.
#
# **Monitoring and Iteration**:
# - Use analytics tools to track user engagement and acquisition metrics.
# - Gather user feedback and refine marketing strategies based on performance data.
#
# **Partnerships**:
# - Collaborate with local gyms and corporate wellness programs to expand reach and increase user adoption.
#
# ### Conclusion
#
# By following this structured approach, the startup can effectively launch a mobile app and achieve the goal of acquiring 10,000 users within six months. The combination of a well-defined app concept, an MVP that meets user needs, a strategic marketing plan, and targeted user acquisition tactics will create a strong foundation for success, all within the constraints of a $50,000 budget and a small team. Regular monitoring and willingness to iterate based on user feedback will ensure continued growth and engagement.

# %% [markdown]
# The `LeastToMostSolver` class orchestrates the complete three-stage process: decompose the problem into sub-problems ordered by difficulty, solve each sequentially using previous solutions as context, and synthesize a comprehensive final answer. This structured approach handles complex problems that would overwhelm direct solving.
#
# ## Compare with direct solving
# To appreciate Least-to-Most's value, let's compare it with asking the LLM to solve complex problems directly. Direct solving requires handling all complexity simultaneously, while Least-to-Most builds understanding incrementally.

# %%
def solve_directly(problem: str) -> str:
    """
    Solve problem directly without decomposition.
    """
    response = llm.invoke([HumanMessage(content=problem)])
    return response.content


# Compare approaches
comparison_problem = "Design a complete employee onboarding system for a remote-first company that integrates training, equipment setup, team introductions, and compliance documentation."

print("=" * 80)
print("COMPARISON: Least-to-Most vs Direct Solving")
print("=" * 80)

print("\n[Method 1: Direct Solving]")
print("-" * 40)
direct = solve_directly(comparison_problem)
print(direct)

print("\n[Method 2: Least-to-Most]")
print("-" * 40)
ltm_result = solver.solve(comparison_problem, verbose=False)
print(ltm_result['final_answer'])
# Out:
# ================================================================================
# COMPARISON: Least-to-Most vs Direct Solving
# ================================================================================
#
# [Method 1: Direct Solving]
# ----------------------------------------
# Designing a complete employee onboarding system for a remote-first company involves creating a structured process that ensures new hires feel welcomed, informed, and equipped to succeed in their roles. Below is a comprehensive outline for such a system, integrating training, equipment setup, team introductions, and compliance documentation.
#
# ### Employee Onboarding System
#
# #### 1. Pre-Onboarding Phase (1-2 weeks before start date)
#
# **1.1 Welcome Email**
# - Send a personalized welcome email that includes:
#   - Start date and time
#   - Overview of the onboarding process
#   - Introduction to the company culture and values
#   - Links to the company website and social media
#
# **1.2 Onboarding Portal Access**
# - Grant access to an onboarding portal where new hires can:
#   - Review the onboarding schedule
#   - Access necessary documents and resources
#   - Complete pre-employment forms
#
# **1.3 Equipment Setup**
# - Coordinate with IT to prepare equipment (laptop, monitor, accessories) and software (VPN, communication tools).
# - Send a checklist of items that will be shipped to the employee's home address.
# - Provide instructions for setting up equipment and troubleshooting common issues.
#
# **1.4 Compliance Documentation**
# - Send necessary compliance documents (tax forms, NDAs, etc.) for completion.
# - Include links to the employee handbook, code of conduct, and any relevant policies.
#
# #### 2. Onboarding Week (Week 1)
#
# **2.1 Day 1 Orientation**
# - Virtual orientation session covering:
#   - Company history, mission, and values
#   - Overview of products/services
#   - Organizational structure and key team members
#   - HR policies and benefits overview
#
# **2.2 Training Modules**
# - Assign mandatory training modules, including:
#   - Compliance training (data protection, harassment prevention)
#   - Role-specific training (tools, processes)
#   - Company culture and values training
# - Use an LMS (Learning Management System) to track progress and completion.
#
# **2.3 Team Introductions**
# - Schedule virtual meet-and-greet sessions with team members.
# - Assign a buddy or mentor for the new hire to help navigate the first few weeks.
# - Encourage team members to share personal introductions and fun facts.
#
# **2.4 Daily Check-ins**
# - Conduct daily check-ins with HR and the direct manager to address any questions or concerns.
# - Use these check-ins to gather feedback on the onboarding process.
#
# #### 3. Ongoing Training and Development (Weeks 2-4)
#
# **3.1 Continued Learning**
# - Provide access to additional training resources (webinars, online courses) relevant to the employee's role.
# - Encourage participation in team meetings and project discussions.
#
# **3.2 Feedback Loop**
# - Schedule a formal feedback session at the end of Week 2 to discuss the onboarding experience and any challenges faced.
# - Use surveys to gather insights from new hires about the onboarding process.
#
# **3.3 Performance Goals**
# - Work with the manager to set performance goals and expectations.
# - Establish a timeline for performance reviews (30, 60, 90 days).
#
# #### 4. Compliance and Documentation (Ongoing)
#
# **4.1 Document Management**
# - Ensure all compliance documents are signed and stored securely in the company's HR system.
# - Send reminders for any upcoming compliance training or document renewals.
#
# **4.2 Regular Updates**
# - Keep new hires updated on policy changes, compliance requirements, and company news through newsletters or internal communication channels.
#
# #### 5. Community Building (Ongoing)
#
# **5.1 Team-Building Activities**
# - Organize virtual team-building activities (game nights, coffee chats) to foster connections.
# - Encourage participation in company-wide events and initiatives.
#
# **5.2 Social Platforms**
# - Create channels on communication platforms (Slack, Microsoft Teams) for informal interactions (hobbies, interests).
# - Promote employee resource groups (ERGs) and affinity groups to enhance community.
#
# #### 6. Evaluation and Improvement
#
# **6.1 Onboarding Review**
# - After three months, conduct a comprehensive review of the onboarding process.
# - Gather feedback from new hires and their managers to identify areas for improvement.
#
# **6.2 Continuous Improvement**
# - Regularly update onboarding materials and training modules based on feedback and evolving company needs.
# - Benchmark against industry best practices to ensure the onboarding process remains effective and engaging.
#
# ### Conclusion
#
# This onboarding system is designed to create a structured, supportive, and engaging experience for new employees in a remote-first company. By integrating training, equipment setup, team introductions, and compliance documentation, the system ensures that new hires are well-prepared and feel like part of the team from day one.
#
# [Method 2: Least-to-Most]
# ----------------------------------------
#
# === Sequential Solving ===
# Solving 4 sub-problems from simplest to most complex...
#
# [Sub-problem 1/4]
# Question: Define the Onboarding Process Framework**: Establish a clear outline of the onboarding process, including the key stages (e.g., pre-boarding, first week, first month). Identify the essential components that need to be included in each stage, such as training schedules, equipment needs, and compliance requirements.
# Answer: ### Onboarding Process Framework for a Remote-First Company
#
# #### Key Stages of the Onboarding Process
#
# 1. **Pre-Boarding (1-2 weeks before start date...
#
# [Sub-problem 2/4]
# Question: Create a Training Program**: Develop a structured training program that includes essential skills and knowledge for new hires. This should consist of online training modules, live sessions, and resources that cover company policies, tools, and job-specific tasks. Ensure that training materials are accessible and engaging for remote employees.
# Answer: ### Structured Training Program for New Hires in a Remote-First Company
#
# #### Overview
# The training program is designed to equip new hires with essent...
#
# [Sub-problem 3/4]
# Question: Set Up Equipment and Technology**: Design a streamlined process for equipping new hires with the necessary tools and technology. This includes selecting hardware (laptops, monitors, etc.), software (communication tools, project management platforms), and ensuring that IT support is available for setup and troubleshooting. Establish a timeline for equipment delivery and setup prior to the employee’s start date.
# Answer: ### Streamlined Equipment and Technology Setup Process for New Hires
#
# #### Overview
# To ensure new hires are fully equipped with the necessary hardware...
#
# [Sub-problem 4/4]
# Question: Facilitate Team Introductions and Compliance Documentation**: Create a system for introducing new employees to their teams and key stakeholders, which may include virtual meet-and-greets or team-building activities. Additionally, establish a process for collecting and managing compliance documentation (e.g., tax forms, non-disclosure agreements) in a secure and efficient manner, ensuring that all required paperwork is completed and submitted in a timely manner.
# Answer: ### System for Facilitating Team Introductions and Managing Compliance Documentation
#
# #### 1. Facilitating Team Introductions
#
# To ensure new employees...
#
# ### Comprehensive Employee Onboarding System for a Remote-First Company
#
# Designing an effective onboarding system for a remote-first company requires a structured approach that integrates training, equipment setup, team introductions, and compliance documentation. This comprehensive system ensures that new hires are well-prepared, engaged, and integrated into the company culture from day one.
#
# #### 1. Onboarding Process Framework
#
# The onboarding process is divided into three key stages: **Pre-Boarding**, **First Week**, and **First Month**. Each stage includes essential components to ensure a smooth transition for new employees.
#
# - **Pre-Boarding (1-2 weeks before start date)**
#   - **Welcome Email:** Personalized welcome with start date and first-day agenda.
#   - **Equipment Setup:** Identify, order, and ship necessary hardware (laptops, monitors) and provide setup instructions for software.
#   - **Documentation:** Send compliance documents (tax forms, NDAs) for electronic signature, along with an employee handbook.
#   - **Access Provisioning:** Set up accounts for essential tools (email, project management software) and share login credentials securely.
#
# - **First Week**
#   - **Orientation Session:** Conduct a virtual meeting covering company history, mission, and structure.
#   - **Training Schedule:** Provide a detailed training plan including departmental functions, role-specific training, and compliance training.
#   - **Team Introductions:** Schedule virtual meet-and-greets with team members and assign a buddy for support.
#   - **Feedback Mechanism:** Set up a check-in meeting to gather feedback on the onboarding experience.
#
# - **First Month**
#   - **Ongoing Training:** Continue role-specific training and provide access to additional resources.
#   - **Performance Expectations:** Outline performance goals and schedule one-on-one meetings to discuss progress.
#   - **Integration Activities:** Encourage participation in team-building activities and social events.
#   - **Compliance Check:** Ensure all compliance documentation is completed and review training understanding.
#
# #### 2. Structured Training Program
#
# The training program is designed to equip new hires with essential skills and knowledge through a mix of online modules, live sessions, and accessible resources.
#
# - **Training Modules**
#   - **Company Overview:** Introduction to company culture and policies through interactive videos and e-learning modules.
#   - **Tools and Technology:** Live demos and workshops on communication and project management tools.
#   - **Role-Specific Training:** In-depth training tailored to the new hire’s role, combining live sessions and guided practice.
#
# - **Live Training Sessions**
#   - **Weekly Check-Ins:** Virtual meetings to discuss progress and address questions.
#   - **Mentorship Meetings:** One-on-one sessions with assigned mentors for guidance.
#
# - **Resources and Support**
#   - **Resource Library:** Centralized access to training materials, recorded sessions, and FAQs.
#   - **Feedback Mechanism:** Surveys and feedback forms to assess training effectiveness.
#
# - **Engagement Strategies**
#   - **Gamification:** Incorporate quizzes and challenges to enhance engagement.
#   - **Interactive Discussions:** Facilitate forums for sharing insights and experiences.
#
# #### 3. Streamlined Equipment and Technology Setup
#
# To ensure new hires are equipped with necessary tools, a streamlined setup process is established.
#
# - **Hardware Selection:** Standardized equipment packages including laptops, monitors, and accessories tailored to role requirements.
# - **Software Provisioning:** Automated installation of essential software (communication tools, project management software, security measures).
# - **IT Support Availability:** Dedicated IT personnel for onboarding support, with setup guides and video tutorials for assistance.
# - **Timeline for Delivery and Setup:** Equipment ordered and delivered 1-2 weeks before the start date, with a virtual IT check-in on Day 1.
#
# #### 4. Facilitating Team Introductions and Compliance Documentation
#
# A system for introducing new employees to their teams and managing compliance documentation is crucial for fostering integration and ensuring legal adherence.
#
# - **Team Introductions**
#   - **Virtual Meet-and-Greets:** Structured introductions with team members in the first week.
#   - **Team-Building Activities:** Scheduled icebreakers and monthly social events to build camaraderie.
#   - **Ongoing Engagement:** Implement a buddy system for regular check-ins and informal conversations.
#
# - **Managing Compliance Documentation**
#   - **Documentation Checklist:** Pre-boarding checklist of required compliance documents.
#   - **Digital Document Package:** Secure electronic signing of documents via platforms like DocuSign.
#   - **Secure Document Management:** Use a cloud-based system for storing compliance documents with restricted access.
#   - **Compliance Tracking:** Implement a dashboard for HR to monitor document submission status and follow up as needed.
#
# ### Summary
#
# This comprehensive employee onboarding system for a remote-first company integrates training, equipment setup, team introductions, and compliance documentation into a cohesive framework. By following a structured onboarding process that encompasses pre-boarding, the first week, and the first month, the company can ensure that new hires are engaged, well-equipped, and integrated into the company culture from day one. Regular feedback and continuous improvement mechanisms further enhance the onboarding experience, fostering a sense of belonging and collaboration within the organization.

# %% [markdown]
# This comparison reveals Least-to-Most's systematic approach. While direct solving might produce reasonable answers quickly, Least-to-Most ensures comprehensive coverage by explicitly breaking down and addressing each aspect and provides transparent reasoning process. The decomposition forces systematic thinking that direct solving might miss.
#
# Least-to-Most prompting addresses complex problems through progressive decomposition and sequential solving. By breaking problems into simpler sub-problems and solving them in order of increasing difficulty, we handle complexity that would overwhelm all-at-once approaches.
#
# **When to use Least-to-Most:**
# - Complex problems with natural sub-problems.
# - Hierarchical reasoning tasks.
# - Problems where later steps depend on earlier ones.
# - Compositional questions.
# - Multi-step proofs or derivations.
#
# **Implementation tips:**
# - Order sub-problems from simplest to most complex.
# - Ensure each sub-problem builds on previous ones.
# - Provide all previous solutions as context.
# - Synthesize sub-solutions into coherent whole.
#
# **Comparison with alternatives:**
# - **vs direct solving**: More systematic but slower.
# - **vs chain-of-thought**: More structured decomposition.
# - **vs tree-of-thoughts**: Linear progression vs exploration.
#
# Least-to-Most demonstrates that tackling complexity incrementally - from least to most difficult - often produces better results than attacking everything simultaneously.
